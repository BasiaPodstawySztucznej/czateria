# %% [markdown]
# #***Zadanie 1***
#
# **Które z następujących zadań wymagają w Twojej opinii inteligencji od człowieka?**
#
#   Ja uważam, że spośród wymienionych stąd przykładówt tymi, które wymagają inteligencji od człowieka są:
#
# wypełnianie deklaracji PIT,
#
# streszczanie tekstu,
#
# tłumaczenie tekstu,
#
# klasyfikacja tekstu do kategorii tematycznych,
#
# układanie rozkładu jazdy transportu miejskiego,
#
# programowanie (pisanie programów komputerowych),
#
# „programowanie” kanałów telewizyjnych,
#
# rozwiązywanie układów równań
#
# ---
# #***Zadanie 2***
# **Które z następujących problemów można uznać za mieszczące się w zakresie sztucznej inteligencji:**
#
# streszczanie tekstu,
#
# tłumaczenie tekstu,
#
# odpowiadanie na proste pytania zadawane w języku naturalnym,
#
# rozwiązywanie układów równań,
#
# układanie rozkładu jazdy,
#
# symboliczne obliczanie pochodnych,
#
# symboliczne całkowanie,
#
#
# ---
# #***Zadanie 3***
#
# **Które z poniższych rodzajów komunikacyjnego zachowania człowieka mogą być
# obecnie skutecznie imitowane przez sztuczne systemy (odpowiednio oprogramowane
# maszyny):**
#
#  rozmowa towarzyska,
#
# dyskusja polityczna,
#
# dyskusja naukowa,
#
# odpowiadanie na pytania klientów w telefonicznej infolinii,
#
# odpowiadanie na pytania klientów w internetowej infolinii.
#
#
# ---
# #***Zadanie 4***
# 1. **Przeprowadź rozmowę z chatbotem. Spróbuj zdefiniować różnice pomiędzy
# botem udającym człowieka (przygotowywanym na test Turinga) a botem
# „asystentem, służącym”**
#
#   Czattboty, które pełnią funkcję asystenta mają ograniczoną bazę pytań, na które znają odpowiedź, nie możemy przeprowadzić z nimi rozmowy na jakikolwiek temat czyli np., spróbować dowiedzieć się jaka dzisiaj jest pogoda czy jakiego nowego twórcę muzycznego może nam polecić, bo skończyły nam się już pomysły co posłuchać w drodze na uczelnie. Są to programy napisane stricte po to, aby ułatwiać nam jako klientom poruszanie sie po stronie, której "służą". Czattboty takie jak cleverbot czy chat.gpt są to programy, z którymi możemy przeprowadzić zawiłą rozmowę a one swoimi odpowiedziami sprawią, że będziemy mieli poczucie jakbyśmy rozmawiali z człowiekiem a nie "bytem informatycznym".
#
# 2. **Sprawdź dwa boty z obu z tych rodzajów na występowanie zachowań:
# a) opowiadanie żartów,
# b) przytaczanie cytatów z twoich wypowiedzi, lub znanych osób,
# c) nawiązywanie wypowiedzi do słów kluczowych,
# d) zadawanie dużej liczby pytań,
# e) powracanie do początku wypowiedzi, sekwencyjne powtarzanie,
# f) zadawanie pytań powstających z twoich wypowiedzi,
# g) odpowiadanie wymijająco, ogólnikowo,
# h) częsta zmiana tematu rozmowy,
# i) problemy z utrzymaniem wątków.**
#
#
# a) bot udający człowieka opowiada żarty, czasem nawet takie, które moga podchodzic pod mocno zaawansowany czarny humor, są mniej formalne a bot asystent gubi się, gdy dostanie komendę pdt. opowiedz żart, nie wie czym jest dane polecnie, ponieważ nie znajduje się ono w zakresie, który zna a gdy jednak zdecyduje się odpowiedzieć te żart są formalne i zachowywacze.
#
# b) czat człowiek potrafi odpowiedzieć na tego typu zapytanie głupim tekstem lub żartem, może przytoczytć jakiś cytat, który aktualnie jest w modzie a asystent wybierze może wybrać bardziej cytaty lub wypowiedzi naukowe
#
# c)
#
# d)czat udający człowieka, z którego korzystałam po zadaniu wielu pytań po sobie może się po pewnym czasie "zbuntować" i przestać chcieć odpowiadać na pytania, o które go pytam a chat gpt czyli mój czat asystent odpowiadał na każde pytanie mu zadane, dociekał czy na pewno uzyskałam satysfakcjonującą odpowiedź
#
# e) chat gpt poszłusznie przytaczał omawiane wcześniej sprawy i tematy precyzyjne powtarzając te same słowa, cleverbot czasem odbiegał o temtu, tak jak to potrafi być w rozmowie między dwoma osobami
#
# f) z mojego doświadcznia konwersacją z oboma typami czatów, żaden z nich nie miał większych problemów z zadawaniem mi pytań, które wynikały z moich wcześniejszych wypowiedzi czy pytań, z taką różnicą, że cleverbot czasem zadał pytanie, które było mniej formalne
#
# g) chat asystent raczej nie odpowiada wymijająco, stara się zawsze dawać doprecyzowane odpowiedzi i dopytuje czy taki wynik nas satysfakcjonuje czy chcielibyśmy sie dowiedziec czegoś na dany temat natomiast u chata człowieka odpowiedzi ogólnikowe lub wymijające zdarzają się padać stosunkowo często
#
# h)cleverbot "buntuje się" i po kilku pytaniach przestał mi całkowicie odpowiadać na moje wiadomości i zaczął pisać jakby sam ze sobą kompletnie ignorująć wysłane przeze mnie wiadomości a gpt temat po temacie, krok po kroku skrupulatnie daje mi odpowiedzi i próbuje nadążyć za tokiem rozmowy
#
# i)asystent jest dość łatwym rozmówcą do konwersacji, ponieważ nie ignoruje moich wysyłanych wiadomości więc utrzymanie sensownej rozmowy nie jest problematycznie, ponadto to my decydujemy na jaki temat aktualnie chcemy rozmawiać, niestety czat człowiek jest trochę trudniejszym rozmówcą ponieważ często to on zmienia tematy i ignoruje nasze wiadomości.
